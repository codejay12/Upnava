# %%
from langchain_core.messages import AIMessage, BaseMessage, HumanMessage
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.chat_models import init_chat_model
import os

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an essay assistant tasked with writing excellent 5-paragraph essays."
            " Generate the best essay possible for the user's request."
            " If the user provides critique, respond with a revised version of your previous attempts.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)
os.environ["GOOGLE_API_KEY"] = "AIzaSyBOcm3skWqRSBdHSkQ230o47KQRVoZf3hQ"
llm = init_chat_model("google_genai:gemini-2.0-flash")
generate = prompt | llm

# %%
essay = ""
request = HumanMessage(
    content="Write an essay on why the little prince is relevant in modern childhood"
)
for chunk in generate.stream({"messages": [request]}):
    print(chunk.content, end="")
    essay += chunk.content
# Out:
# ## The Enduring Wisdom of a Child: Why The Little Prince Still Matters
#
# Antoine de Saint-Exupéry's *The Little Prince*, a seemingly simple tale of a pilot stranded in the desert and his encounter with a young prince from a distant asteroid, continues to resonate deeply with readers of all ages. However, its relevance to modern childhood, a world saturated with technology and often characterized by a fast-paced, materialistic culture, is particularly profound. The book's timeless themes of genuine connection, the importance of imagination, and the dangers of superficiality offer crucial lessons for children navigating the complexities of the 21st century.
#
# One of the most significant ways *The Little Prince* remains relevant is its emphasis on the importance of authentic connection. In a world increasingly dominated by virtual interactions, the little prince's journey highlights the value of building meaningful relationships based on understanding, empathy, and shared experiences. His interactions with the fox, who teaches him the concept of taming and the responsibility that comes with love, serve as a powerful reminder that true connection requires effort, patience, and vulnerability. This message is especially important for children growing up in an age where online friendships can often feel fleeting and superficial, encouraging them to seek out and nurture genuine bonds with others.
#
# Furthermore, *The Little Prince* champions the power of imagination and the importance of seeing the world with childlike wonder. The prince's ability to see a sheep inside a box, or to understand the baobabs as a threat to his tiny planet, demonstrates the boundless potential of a creative mind. This imaginative spirit is often stifled in modern childhood by structured activities, standardized testing, and the pressure to conform. By celebrating the beauty of simple things and encouraging readers to look beyond the surface, *The Little Prince* reminds children to cultivate their imagination and to resist the pressure to abandon their unique perspectives.
#
# Moreover, the book critiques the superficiality and materialism that often pervade modern society. The characters the little prince encounters on his journey – the king obsessed with power, the conceited man seeking admiration, the businessman consumed by numbers – represent the emptiness and lack of fulfillment that can result from prioritizing external validation and material possessions. This critique is particularly pertinent in a world where children are constantly bombarded with advertisements and messages that equate happiness with acquiring the latest gadgets and trends. *The Little Prince* encourages children to question these values and to seek fulfillment in more meaningful pursuits, such as kindness, compassion, and personal growth.
#
# In conclusion, *The Little Prince* remains a powerful and relevant story for modern children. Its timeless themes of authentic connection, the importance of imagination, and the dangers of superficiality offer valuable lessons for navigating the complexities of the 21st century. By encouraging children to cultivate meaningful relationships, embrace their imagination, and question societal values, *The Little Prince* empowers them to become more compassionate, thoughtful, and ultimately, more fulfilled individuals. The enduring wisdom of this little prince continues to guide young readers on their own journeys of self-discovery, reminding them to see the world with their hearts and to cherish the things that truly matter.

# %%
reflection_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a teacher grading an essay submission. Generate critique and recommendations for the user's submission."
            " Provide detailed recommendations, including requests for length, depth, style, etc.",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)
reflect = reflection_prompt | llm

# %%
reflection = ""
for chunk in reflect.stream({"messages": [request, HumanMessage(content=essay)]}):
    print(chunk.content, end="")
    reflection += chunk.content
# Out:
# Okay, I understand. Here's my essay:
#
# The Little Prince, written by Antoine de Saint-Exupéry, is a timeless novella that continues to resonate with readers of all ages. While published in 1943, its themes of imagination, friendship, and the dangers of superficiality remain remarkably relevant in modern childhood. In a world increasingly dominated by technology and consumerism, The Little Prince offers children a valuable reminder of the importance of human connection, critical thinking, and seeing the world with childlike wonder.
#
# One of the most significant ways The Little Prince remains relevant is its emphasis on imagination. In the story, the little prince travels from planet to planet, encountering adults who have lost their sense of wonder. The businessman, for example, is obsessed with counting stars, seeing them only as possessions rather than objects of beauty and mystery. Similarly, the geographer refuses to explore the world himself, relying instead on the accounts of explorers. These characters stand in stark contrast to the little prince, who sees the world with fresh eyes and is always eager to learn and explore. In modern childhood, children are often pressured to conform and focus on academic achievement, leaving little room for imaginative play. The Little Prince encourages children to resist this pressure and to cultivate their own unique perspectives and creative abilities, reminding them that true understanding comes from experience and reflection, not just rote memorization.
#
# Furthermore, the book’s exploration of friendship is profoundly relevant in today’s world. The relationship between the little prince and the fox highlights the importance of patience, trust, and emotional connection. The fox teaches the little prince that “it is only with the heart that one can see rightly; what is essential is invisible to the eye.” This message is particularly important in an age where social interactions are increasingly mediated by technology. While social media can connect children with others around the world, it can also lead to superficial relationships and a lack of genuine connection. The Little Prince reminds children that true friendship requires time, effort, and vulnerability, and that the most meaningful relationships are built on mutual respect and understanding. The act of "taming," as the fox explains, is about creating bonds and taking responsibility for those you care about, a lesson crucial for navigating the complexities of social relationships in the digital age.Finally, The Little Prince critiques the adult world's obsession with material possessions and superficial appearances, a critique that is particularly salient in modern consumer culture. The various characters the little prince encounters on his journey are consumed by their own self-importance and material desires. This serves as a cautionary tale for children who are constantly bombarded with advertisements and messages that equate happiness with buying things. The Little Prince encourages children to question these values and to prioritize experiences, relationships, and personal growth over material wealth. By valuing the rose for its unique qualities rather than its monetary worth, the little prince demonstrates the importance of appreciating the intrinsic value of things and people, a lesson that can help children resist the pressures of consumerism and develop a more meaningful sense of self.
#
# In conclusion, The Little Prince remains a powerful and relevant story for modern children. Its timeless themes of imagination, friendship, and anti-materialism offer a valuable counterpoint to the pressures and challenges of contemporary childhood. By encouraging children to cultivate their imaginations, build meaningful relationships, and question the values of consumer culture, The Little Prince empowers them to navigate the complexities of the modern world with wisdom, compassion, and a sense of wonder. It is a book that should be read and reread, its simple prose and profound message continuing to inspire generations of young readers.

# %%
for chunk in generate.stream(
    {"messages": [request, AIMessage(content=essay), HumanMessage(content=reflection)]}
):
    print(chunk.content, end="")
# Out:
# This is a very solid essay! You've clearly understood the prompt and provided a well-organized and thoughtful response. Your thesis statement is clear, your body paragraphs are focused and supported with evidence, and your conclusion effectively summarizes your argument. The connections you draw between the book's themes and the challenges of modern childhood are insightful.Here's a more detailed breakdown with suggestions for improvement:
#
# **Strengths:**
#
# *   **Clear Thesis:** The thesis statement in the introduction clearly states the essay's main argument and provides a roadmap for the rest of the essay.
# *   **Strong Topic Sentences:** Each body paragraph begins with a strong topic sentence that directly relates to the thesis statement and introduces the main point of the paragraph.
# *   **Relevant Examples:** You've chosen relevant examples from the book (the businessman, the geographer, the fox, the rose) to support your claims.
# *   **Effective Analysis:** You don't just summarize the examples; you analyze *why* they are relevant to modern childhood. You explain how the characters and situations in the book relate to the challenges and pressures that children face today.
# *   **Well-Organized:** The essay is logically organized with a clear introduction, body paragraphs, and conclusion. The transitions between paragraphs are smooth and help to maintain the flow of the essay.
# *   **Good Understanding of Modern Childhood:** You demonstrate an understanding of the influences of technology and consumerism on modern children.
# *   **Strong Conclusion:** The conclusion effectively summarizes the main points of the essay and leaves the reader with a lasting impression.
#
# **Areas for Improvement:***   **Deeper Dive into "Modern Childhood":** While you touch on technology and consumerism, you could explore other aspects of modern childhood in more depth. Consider mentioning things like:
#     *   **Increased Academic Pressure:** The pressure to perform well in school starts younger and is often more intense than in previous generations.
#     *   **Mental Health Concerns:** Anxiety and depression are increasingly prevalent among children and adolescents.
#     *   **Changing Family Structures:** Many children grow up in single-parent households or blended families.
#     *   **Exposure to Global Issues:** Children are more aware of global issues like climate change and social injustice.
# *   **Nuance and Counterarguments:** While you argue for the book's relevance, consider briefly acknowledging potential counterarguments. For example:
#     *   Some might argue that the book is too simplistic or sentimental for modern children who are exposed to more complex and sophisticated narratives.
#     *   Others might argue that the book's focus on traditional values is outdated in a more progressive and diverse world.
#     Addressing these counterarguments will strengthen your overall argument by demonstrating that you have considered different perspectives.
# *   **Specificity in Examples:** While your examples are relevant, you could make them even more impactful by providing more specific details or direct quotes from the book. For example, instead of just saying "the businessman is obsessed with counting stars," you could include a quote like, "I own the stars, because no one before me ever thought of owning them."
# *   **Connect the Dots Even More Explicitly:** In a few places, the connection between the example from the book and modern childhood could be made more explicit. Don't assume the reader will automatically see the connection; spell it out for them.
#
# **Revised Sections (Examples):**
#
# Here are a few examples of how you could revise specific sections to address these suggestions:
#
# *   **Introduction (Adding Nuance):**
#
#     "The Little Prince, written by Antoine de Saint-Exupéry, is a timeless novella that continues to resonate with readers of all ages. While published in 1943, its themes of imagination, friendship, and the dangers of superficiality remain remarkably relevant in modern childhood. *Of course, some might argue that its simple narrative and focus on traditional values feel outdated in an era of complex storytelling and diverse perspectives.* However, in a world increasingly dominated by technology, academic pressures, and consumerism, The Little Prince offers children a valuable reminder of the importance of human connection, critical thinking, and seeing the world with childlike wonder."
#
# *   **Imagination Paragraph (Adding Specificity and Explicit Connection):**
#
#     "One of the most significant ways The Little Prince remains relevant is its emphasis on imagination. In the story, the little prince travels from planet to planet, encountering adults who have lost their sense of wonder. The businessman, for example, is obsessed with counting stars, declaring, "I own the stars, because no one before me ever thought of owning them." He sees them only as possessions rather than objects of beauty and mystery. This illustrates the adult world's tendency to quantify and control, stifling the natural sense of wonder. In modern childhood, children are often pressured to conform and focus on academic achievement, with standardized testing and rigorous curricula leaving little room for imaginative play. This pressure can lead to anxiety and a diminished sense of creativity. The Little Prince encourages children to resist this pressure and to cultivate their own unique perspectives and creative abilities, reminding them that true understanding comes from experience and reflection, not just rote memorization. By embracing the spirit of the little prince, children can safeguard their innate curiosity and develop the critical thinking skills needed to navigate an increasingly complex world."
#
# **Overall Recommendation:**
#
# Your essay is already quite strong. By incorporating these suggestions, you can elevate it to an even higher level. Focus on adding more specific details, making the connections between the book and modern childhood even more explicit, and acknowledging potential counterarguments. Good job!
#
# I'm ready for your next revision! Let me know if you have any questions about my feedback.

# %%
from typing import Annotated,List, Sequence
from langgraph.graph import END,START,StateGraph
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver
from typing_extensions import TypedDict

class State(TypedDict):
  messages: Annotated[list,add_messages]
  
async def generation_node(state: State) -> State:
  return {"messages":[await generate.ainvoke(state['messages'])]}

# %%
import datetime
import operator
import os
from typing import Annotated, TypedDict

from dotenv import load_dotenv
from langchain_core.messages import AnyMessage, HumanMessage, SystemMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import END, StateGraph
from sendgrid import SendGridAPIClient
from sendgrid.helpers.mail import Mail

from agents.tools.flights_finder import flights_finder
from agents.tools.hotels_finder import hotels_finder

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

class Agent:

    def __init__(self):
        self._tools = {t.name: t for t in TOOLS}
        self._tools_llm = ChatOpenAI(model='gpt-4o').bind_tools(TOOLS)

        builder = StateGraph(AgentState)
        builder.add_node('call_tools_llm', self.call_tools_llm)
        builder.add_node('invoke_tools', self.invoke_tools)
        builder.add_node('email_sender', self.email_sender)
        builder.set_entry_point('call_tools_llm')

        builder.add_conditional_edges('call_tools_llm', Agent.exists_action, {'more_tools': 'invoke_tools', 'email_sender': 'email_sender'})
        builder.add_edge('invoke_tools', 'call_tools_llm')
        builder.add_edge('email_sender', END)
        memory = MemorySaver()
        self.graph = builder.compile(checkpointer=memory, interrupt_before=['email_sender'])

        print(self.graph.get_graph().draw_mermaid())

    @staticmethod
    def exists_action(state: AgentState):
        result = state['messages'][-1]
        if len(result.tool_calls) == 0:
            return 'email_sender'
        return 'more_tools'

    def email_sender(self, state: AgentState):
        print('Sending email')
        email_llm = ChatOpenAI(model='gpt-4o', temperature=0.1)  # Instantiate another LLM
        email_message = [SystemMessage(content=EMAILS_SYSTEM_PROMPT), HumanMessage(content=state['messages'][-1].content)]
        email_response = email_llm.invoke(email_message)
        print('Email content:', email_response.content)

        message = Mail(from_email=os.environ['FROM_EMAIL'], to_emails=os.environ['TO_EMAIL'], subject=os.environ['EMAIL_SUBJECT'],
                       html_content=email_response.content)
        try:
            sg = SendGridAPIClient(os.environ.get('SENDGRID_API_KEY'))
            response = sg.send(message)
            print(response.status_code)
            print(response.body)
            print(response.headers)
        except Exception as e:
            print(str(e))

    def call_tools_llm(self, state: AgentState):
        messages = state['messages']
        messages = [SystemMessage(content=TOOLS_SYSTEM_PROMPT)] + messages
        message = self._tools_llm.invoke(messages)
        return {'messages': [message]}

    def invoke_tools(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f'Calling: {t}')
            if not t['name'] in self._tools:  # check for bad tool name from LLM
                print('\n ....bad tool name....')
                result = 'bad tool name, retry'  # instruct LLM to retry if bad
            else:
                result = self._tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print('Back to the model!')
        return {'messages': results}
